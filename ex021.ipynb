# %%
# !pip install pygame

import pygame

pygame.init()
pygame.mixer.music.load('blackbooksloop.mp3')
pygame.mixer.music.play()
input()
pygame.event.wait()
# Out:
# ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-4302b8a4d8e3> in <cell line: 0>()
#       4
#       5 pygame.init()
# ----> 6 pygame.mixer.music.load('blackbooksloop.mp3')
#       7 pygame.mixer.music.play()
#       8 input()
#
# error: mixer not initialized
