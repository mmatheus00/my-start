# %%
# crie um programa que leia o nome e o preco de varios produtos.
# o programa devera perguntar se o usuario quer continuar.
# no final, mostre:

# qual e o total gasto na compra
# quantos produtos custam mais de R$1000
# qual e o nome do produto mais barato

# %%
maisbarato = total = cont = maiscaro = 0
nomebarato = ''

print('~'*46)
print(' '*6,'OUTLET - PRA GRINGO E MAI$ CARO')
print('~'*46)

while True:
  produto = str(input('Nome produto: ')).title().strip()
  preco = float(input('Preco produto: R$'))
  cont += 1
  total += preco

  if preco > 1000:
    maiscaro += 1

  if cont == 1:
    maisbarato = preco
    nomebarato = produto
  else:
    if preco <= maisbarato:
      maisbarato = preco
      nomebarato = produto

  print('=-'*23)
  print(' '*10,'ADICIONADO AO CARRINHO!')
  print('=-'*23)

  print('\n')
  cad = str(input('Mais produtos? [S/N]')).title().strip()[0]
  print('\n')
  while cad != 'S' and cad != 'N':
    cad = str(input('Mais produtos? [S/N]')).title().strip()[0]

  if cad == 'N':
    break
print('\n')
print('-'*46)
print(' '*12,'REALIZAR PAGAMENTO')
print('-'*46)
print(f'''
Total gasto: R${total:.2f}
Produtos que custam mais de mil reais: {maiscaro}
Produto mais barato: {nomebarato}, R${maisbarato:.2f}
''')
print('-'*46)

# %% [markdown]
# Correção Guanabara

# %%
total = totmil = menor = cont = 0
barato = ' '
while True:
    produto = str(input('Nome do Produto: '))
    preco = float(input('Preço: R$'))
    cont += 1
    total += preco
    if preco > 1000:
        totmil += 1
    if cont == 1 or preco < menor:
        menor = preco
        barato = produto
    resp = ' '
    while resp not in 'SN':
        resp = str(input('Quer continuar? [S/N] ')).strip().upper()[0]
    if resp == 'N':
        break
print(f'{:-^40}'.format(' FIM DO PROGRAMA '))
print(f'O total da compra foi R${total:.2f}')
print(f'Temos {totmil} produtos custando mais de R$1000.00')
print(f'O produto mais barato foi {barato} que custa R${menor:.2f}')
