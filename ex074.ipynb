# %%
# Crie um programa que vai gerar cinco numeros aleatorios e colocar em uma tupla.
# Depois disso, mostre a listagem de numeros gerados e tambem indique o menor e o maior valor que estao na tupla.

# %%
from random import randint
aleatorio = (randint(1, 10), randint(1, 10), randint(1, 10), randint(1, 10), randint(1, 10))
print(f'Os valores sorteados foram:', end=" ")
for n in aleatorio:
  print(f'{n} ',end='')
print(f'\nO maior numero sorteado foi o {max(aleatorio)}')
print(f'O menor numero sorteado foi o {min(aleatorio)}')
# Out:
# Os valores sorteados foram: 5 8 2 9 1
# O maior numero sorteado foi o 9
# O menor numero sorteado foi o 1
