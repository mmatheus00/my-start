# %%
# Crie um programa que leia um número inteiro e mostre na tela se ele é par ou ímpar.

number = int(input('Digite um número qualquer: '))

if number % 2 == 0:
  print(f'O número {number} é um número par!')
else:
  print(f'O número {number} é um número impar!')
# Out:
# Digite um número qualquer: 4
# O número 4 é um número par!
