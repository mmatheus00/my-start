# %%
# Desenvolva um programa que leia seis números inteiros e mostre a soma apenas daqueles que forem pares.
# Se o valor digitado for ímpar, desconsidere-o.

# %%
soma = 0

for num in range (1, 7):
  user_num = int(input('Digite um número: '))
  if user_num % 2 == 0:
    soma += user_num
print(f'A soma dos números pares é igual a: {soma}!')
# Out:
# Digite um número: 2
# Digite um número: 1
# Digite um número: 0
# Digite um número: 5
# Digite um número: 7
# Digite um número: 9
# A soma dos números pares é igual a: 2!
