# %%
# Crie um programa que leia um número Real qualquer pelo teclado e mostre na tela sua porção inteira.

print('float to int\n')

#também da pra utilizar o trunc
from math import floor

num1 = (float(input('Digite um número real qualquer: ')))
num2 = print(f'A porção inteira de {num1} é {floor(num1)}!')
# Out:
# float to int
#
# Digite um número real qualquer: 9.88
# A porção inteira de 9.88 é 9!
