# %%
# Crie um programa que faça o computador jogar Jokênpo com você.

import time, random

print('--------------------------------THE JKP MASTER AWAKES--------------------------------')
time.sleep(2)
print('Aaahg.. Ahn?.. O quê?.. Quem me acordou???..')
time.sleep(2)
print('Aaaaah.. você..')
time.sleep(2)
print('Fiquei sabendo que você quer me desafiar no Jokênpo... Vamos ver do que você é capaz!!')
time.sleep(2)
print('\n')
print('Jo...')
time.sleep(1)
print('kên...')
time.sleep(1)
print('PÔ!!!')
time.sleep(1)

play = ('Pedra', 'Papel', 'Tesoura')
computador = random.randint(0, 2)

print('''
[0] - Pedra
[1] - Papel
[2] - Tesoura
''')

user_choose = int(input('Digite a sua escolha para derrotar o Mestre!!: '))
print('\n')

print('~~~~'*10)
print(f'Jogador 1 escolheu: {play[user_choose]}!!!')
print(f'THE JKP MASTER escolheu: {play[computador]}!!!')
print('~~~~'*10)
print('\n')

if computador == 0:
  if user_choose == 0:
    print('É um Empate!')
  elif user_choose == 1:
    print('Você Perdeu!')
  elif user_choose == 2:
    print('Você Ganhou!')
  else:
    print('Escolha Inválida!')

elif computador == 1:
  if user_choose == 0:
    print('Você Ganhou!')
  elif user_choose == 1:
    print('É um Empate!')
  elif user_choose == 2:
    print('Você Perdeu!')
  else:
    print('Escolha Inválida!')

elif computador == 2:
  if user_choose == 0:
    print('Você Perdeu!')
  elif user_choose == 1:
    print('Você Ganhou!')
  elif user_choose == 2:
    print('É um Empate!')
  else:
    print('Escolha Inválida!')
# Out:
# --------------------------------THE JKP MASTER AWAKES--------------------------------
# Aaahg.. Ahn?.. O quê?.. Quem me acordou???..
# Aaaaah.. você..
# Fiquei sabendo que você quer me desafiar no Jokênpo... Vamos ver do que você é capaz!!
#
#
# Jo...
# kên...
# PÔ!!!
#
# [0] - Pedra
# [1] - Papel
# [2] - Tesoura
#
# Digite a sua escolha para derrotar o Mestre!!: 3
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-a69d269947bc> in <cell line: 0>()
#      32
#      33 print('~~~~'*10)
# ---> 34 print(f'Jogador 1 escolheu: {play[user_choose]}!!!')
#      35 print(f'THE JKP MASTER escolheu: {play[computador]}!!!')
#      36 print('~~~~'*10)
#
# IndexError: tuple index out of range
