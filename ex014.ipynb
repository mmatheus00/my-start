# %%
#Escreva um programa que converta a temperatura de °C para Fahrenheit

print('Convertendo temperaturas \n')

c = float(input('Digite a temperatura em °C: '))
f = (c * 9 / 5) + 32

print(f'{c}° Celsius corresponde a {f:.1f} Fahrenheit.')
# Out:
# Convertendo temperaturas
#
# Digite a temperatura em °C: 32.1
# 32.1° Celsius corresponde a 89.8 Fahrenheit.
