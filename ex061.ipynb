# %%
# Refaca o desafio 051, lendo o primeiro termo e a razao de uma PA
# mostrando os 10 primeiros termos da progressao utilizando a estrutura while


# ex051

'''
termo = int(input('Digite aqui o primeiro termo: '))
razao = int(input('Digite aqui a razão: '))

seg_termo = (termo + (10 - 1) * razao) + razao
print('\n')

print(f'Esses são os dez primeiros termos dessa progressão aritmética: ', '\n')

for pa in range (termo, seg_termo, razao):
  print(pa, end=' ')
'''

# %%
termo = int(input('Digite aqui o primeiro termo: '))
razao = int(input('Digite aqui a razão: '))

tot = 0
acumm = 1

while acumm <= 10:
  tot = termo + (acumm-1) * razao
  acumm+=1
  print(tot, end=" ")
# Out:
# Digite aqui o primeiro termo: 0
# Digite aqui a razão: 6
# 0 6 12 18 24 30 36 42 48 54
