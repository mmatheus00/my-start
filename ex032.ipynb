# %%
# Faça um programa que leia um ano qualquer e mostre se ele é bissexto

ano = int(input('Digite um ano qualquer e eu vou te dizer se ele foi, é ou será um ano bissexto: '))
bi = ano % 4

if bi == 0:
  print(f'{ano} é bissexto!')
else:
  print(f'{ano} não é bissexto!')
# Out:
# Digite um ano qualquer e eu vou te dizer se ele foi, é ou será um ano bissexto: 2022
# 2022 não é bissexto!
