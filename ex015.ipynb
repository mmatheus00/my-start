# %%
"""
Escreva um programa que pergunte a quantidade de KM percorridos por um carro alugado e
a quantidade de dias pelos quais ele foi alugado. Calcule o preço a pagar, sabendo que o
carro custa R$ 60,00 por dia e R$ 0,15 por KM rodado.
"""

km = (float(input('Qual foi a kilometragem percorrida?: ')))
dias = (int(input('Quantos dias o carro ficou alugado?: ')))

aluguel = (dias*60)+(km*0.15)

print(f'O preço a pagar pelo aluguel do carro é R${aluguel:.2f}!')
# Out:
# Qual foi a kilometragem percorrida?: 400
# Quantos dias o carro ficou alugado?: 5
# O preço a pagar pelo aluguel do carro é R$360.00!
