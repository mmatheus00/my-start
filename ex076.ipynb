# %%
# Crie um programa que tenha uma tupla unica com nomes de produtos e seus respectivos precos na sequencia.
# No final, mostre uma listagem de precos organizando os dados em forma tabular.

# %%
produtos = ('Mouse', 125.99, 'Mousepad', 39.99, 'Teclado', 259.99, 'Fone', 179.99, 'Monitor', 589.99, 'Cadeira', 899.99, 'Led RGB', 29.99)
for pos in range(0, len(produtos)):
  if pos %2 == 0:
    print(f'{produtos[pos]:.<30}', end='')
  else:
    print(f'R${produtos[pos]:.>5.2f}')
# Out:
# Mouse.........................R$125.99
# Mousepad......................R$39.99
# Teclado.......................R$259.99
# Fone..........................R$179.99
# Monitor.......................R$589.99
# Cadeira.......................R$899.99
# Led RGB.......................R$29.99
