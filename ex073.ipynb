# %%
# Crie uma tupla preenchida com os 20 primeiros colocados da tabela do Brasileirao, na ordem de colocacao.
# Depois mostre:

#A Apenas os 5 primeiros colocados.
#B Os ultimos 4 colocados da tabela.
#C Uma lista com os times em ordem alfabetica.
#D Em que posicao da tabela esta o time da chapecoense (serie B em 2025, vou colocar o vascao no lugar. Nesse exato momento esta jogando contra o lanus na Sulamericana, Grupo G, 5 rodada)

# %%
brasileirao = ('Palmeiras', 'Varmengo', 'Bragantino', 'Cruzeirudo', 'Fluminense',
               'Ceara', 'Atletico-MG', 'Bahia', 'Botafogo', 'Corinthians', 'Fortaleza',
               'Mirassol', 'Internacional', 'Vitoria', 'Gremio', 'Sao Paulo', 'Vaxxxco',
               'Juventude', 'Santos com Neymar', 'Sport')

print(f'Os 5 primeiros colocados ate a rodada 8 do Brasileirao 2025: {brasileirao[0:5]}')
print(f'OS laternas: {brasileirao[-4:]}')
print(f'Times em Ordem Alfabetica: {sorted(brasileirao)}')
print(f'Vaxxxcao da massa esta na {brasileirao.index("Vaxxxco")+1}a posicao')

# %% [markdown]
# Correcao Guanabara

# %%
times = ('Corinthians', 'Palmeiras', 'Santos', 'Grêmio',
         'Cruzeiro', 'Flamengo', 'Vasco', 'Chapecoense',
         'Atlético', 'Botafogo', 'Atlético-PR', 'Bahia',
         'São Paulo', 'Fluminense', 'Sport Recife',
         'EC Vitória', 'Coritiba', 'Avaí', 'Ponte Preta',
         'Atlético-GO')

print('--' * 15)
print(f'Lista de times do Brasileirão: {times}')
print('--' * 15)
print(f'Os 5 primeiros são {times[0:5]}')
print('--' * 15)
print(f'Os 4 últimos são {times[-4:]}')
print('--' * 15)
print(f'Times em ordem alfabética: {sorted(times)}')
print('--' * 15)
print(f'O Chapecoense está na {times.index("Chapecoense")+1}ª posição')
