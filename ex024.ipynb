# %%
# Crie um programa que leia o nome de uma cidade e diga se ela começa ou não com o nome "Santo".

print('Analisando sua cidade\n')

cid = (str(input('Em que cidade você nasceu?: '))).strip().title()
print(f'Verificando se sua cidade começa com o nome "Santo": {cid}')
dividido = cid.split()
print ('Santo' in (dividido[0]))


#-----------------------------------------------------------------------------------------------

# Outra solução:

#cid = (str(input('Em que cidade você nasceu?: '))).strip()
#print(cid[:5].upper() == 'SANTO')
# Out:
# Analisando sua cidade
#
# Digite o nome da sua cidade: SANTO JK
# Verificando se sua cidade começa com o nome "Santo": Santo Jk
# True
